# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv("../scraper/books_raw.csv")

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns)
# Out:
# Shape: (105, 9)
#
# Columns:
# Index(['title', 'category', 'price', 'rating', 'availability',
#        'product_description', 'UPC', 'number_of_reviews', 'product_url'],
#       dtype='str')

# %%
df.head()
# Out:
#                                                title         category   price  \
# 0                            It's Only the Himalayas           Travel  £45.17
# 1                       Libertarianism for Beginners         Politics  £51.33
# 2  Mesaerion: The Best Science Fiction Stories 18...  Science Fiction  £37.59
# 3                                               Olio           Poetry  £23.88
# 4  Our Band Could Be Your Life: Scenes from the A...            Music  £57.25
#
#   rating                                       availability  \
# 0    Two  In stock (19 available) In stock In stock In s...
# 1    Two  In stock (19 available) In stock In stock In s...
# 2    One  In stock (19 available) In stock In stock In s...
# 3    One  In stock (19 available) In stock In stock In s...
# 4  Three  In stock (19 available) In stock In stock In s...
#
#                                  product_description               UPC  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                105 non-null    str
#  1   category             105 non-null    str
#  2   price                105 non-null    str
#  3   rating               105 non-null    str
#  4   availability         105 non-null    str
#  5   product_description  105 non-null    str
#  6   UPC                  105 non-null    str
#  7   number_of_reviews    105 non-null    int64
#  8   product_url          105 non-null    str
# dtypes: int64(1), str(8)
# memory usage: 7.5 KB

# %%
df.describe(include="all")
# Out:
#                           title        category   price rating  \
# count                       105             105     105    105
# unique                      105              29     104      5
# top     It's Only the Himalayas  Sequential Art  £44.18    One
# freq                          1              16       2     23
# mean                        NaN             NaN     NaN    NaN
# std                         NaN             NaN     NaN    NaN
# min                         NaN             NaN     NaN    NaN
# 25%                         NaN             NaN     NaN    NaN
# 50%                         NaN             NaN     NaN    NaN
# 75%                         NaN             NaN     NaN    NaN
# max                         NaN             NaN     NaN    NaN
#
#                                              availability  \
# count                                                 105
# unique                                                  7
# ...

# %%
import pandas as pd

df = pd.read_csv("../scraper/books_raw.csv")

df.shape
# Out:
# (105, 9)

# %%
df["price"] = df["price"].str.replace("£", "", regex=False)
df["price"] = df["price"].astype(float)

df["price"].head()
# Out:
# 0    45.17
# 1    51.33
# 2    37.59
# 3    23.88
# 4    57.25
# Name: price, dtype: float64

# %%
rating_map = {
    "One": 1,
    "Two": 2,
    "Three": 3,
    "Four": 4,
    "Five": 5
}

df["rating"] = df["rating"].map(rating_map)

df["rating"].head()
# Out:
# 0    2
# 1    2
# 2    1
# 3    1
# 4    3
# Name: rating, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                105 non-null    str
#  1   category             105 non-null    str
#  2   price                105 non-null    float64
#  3   rating               105 non-null    int64
#  4   availability         105 non-null    str
#  5   product_description  105 non-null    str
#  6   UPC                  105 non-null    str
#  7   number_of_reviews    105 non-null    int64
#  8   product_url          105 non-null    str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 7.5 KB

# %%
df.describe()
# Out:
#             price      rating  number_of_reviews
# count  105.000000  105.000000              105.0
# mean    34.598857    2.857143                0.0
# std     14.401022    1.375811                0.0
# min     10.160000    1.000000                0.0
# 25%     20.590000    2.000000                0.0
# 50%     34.530000    3.000000                0.0
# 75%     46.910000    4.000000                0.0
# max     59.640000    5.000000                0.0

# %%
category_counts = df["category"].value_counts()

print(category_counts)
# Out:
# category
# Sequential Art        16
# Default               12
# Nonfiction            12
# Fantasy                6
# Poetry                 5
# Young Adult            5
# Romance                5
# History                4
# Childrens              4
# Food and Drink         4
# Add a comment          4
# Philosophy             3
# Fiction                3
# Science Fiction        2
# Music                  2
# Business               2
# Thriller               2
# Mystery                2
# Spirituality           2
# Travel                 1
# Politics               1
# Art                    1
# Contemporary           1
# New Adult              1
# Horror                 1
# Health                 1
# Self Help              1
# Religion               1
# Historical Fiction     1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
category_counts.plot(kind="bar")
plt.title("Number of Books in Each Category")
plt.xlabel("Category")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,4))
df["rating"].value_counts().sort_index().plot(kind="bar")
plt.title("Book Ratings")
plt.xlabel("Rating")
plt.ylabel("Number of Books")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["price"], bins=20)
plt.title("Distribution of Book Prices")
plt.xlabel("Price (£)")
plt.ylabel("Frequency")
plt.show()

# %%
top_books = df.sort_values("price", ascending=False)

top_books[["title", "price"]].head(10)
# Out:
#                                                  title  price
# 102  Thomas Jefferson and the Tripoli Pirates: The ...  59.64
# 59        The Death of Humanity: and the Case for Life  58.11
# 100  The White Cat and the Monk: A Retelling of the...  58.08
# 4    Our Band Could Be Your Life: Scenes from the A...  57.25
# 33                                 The Past Never Ends  56.50
# 34   The Pioneer Woman Cooks: Dinnertime: Comfort C...  56.41
# 72                                   Masks and Shadows  56.40
# 35                     The Secret of Dreadwillow Carse  56.13
# 60   The Electric Pencil: Drawings from Inside Stat...  56.06
# 30                       Birdsong: A Story in Pictures  54.64

# %%
df.groupby("rating")["price"].mean()
# Out:
# rating
# 1    36.443043
# 2    36.916818
# 3    34.574348
# 4    33.250952
# 5    30.565000
# Name: price, dtype: float64

# %%
df.groupby("rating")["price"].mean()
# Out:
# rating
# 1    36.443043
# 2    36.916818
# 3    34.574348
# 4    33.250952
# 5    30.565000
# Name: price, dtype: float64

# %%
df.groupby("rating")["price"].mean().plot(
    kind="bar",
    figsize=(6,4)
)

plt.title("Average Price by Rating")
plt.xlabel("Rating")
plt.ylabel("Average Price (£)")
plt.show()

# %%
from wordcloud import WordCloud

text = " ".join(df["title"])

wordcloud = WordCloud(
    width=1000,
    height=500,
    background_color="white"
).generate(text)

plt.figure(figsize=(15,7))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
df.to_csv("books_cleaned.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x="rating", data=df)
plt.title("Distribution of Book Ratings")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.histplot(df["price"], bins=15, kde=True)

plt.title("Distribution of Book Prices")
plt.xlabel("Price (£)")
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.barplot(
    x="rating",
    y="price",
    data=df
)

plt.title("Average Price by Rating")

plt.show()

# %%
plt.figure(figsize=(10,5))

df["category"].value_counts().head(10).plot(kind="bar")

plt.title("Top 10 Categories")
plt.ylabel("Number of Books")

plt.show()

# %%
top_books = df.sort_values("price", ascending=False).head(10)

plt.figure(figsize=(10,5))

sns.barplot(
    x="price",
    y="title",
    data=top_books
)

plt.title("Top 10 Most Expensive Books")

plt.show()

# %%
from wordcloud import WordCloud

text = " ".join(df["product_description"])

wordcloud = WordCloud(
    width=900,
    height=500,
    background_color="white"
).generate(text)

plt.figure(figsize=(12,6))
plt.imshow(wordcloud)
plt.axis("off")
plt.title("Word Cloud of Book Descriptions")
plt.show()

# %% [markdown]
# # Task 4 - Insights and Interpretation
#
# ## Observation 1
# The dataset contains 105 books distributed across multiple categories with no missing values.
#
# ## Observation 2
# Most books are rated between 2 and 4 stars, while very few books receive the highest rating.
#
# ## Observation 3
# Book prices range approximately from £20 to £60, with an average price of about £34.6.
#
# ## Observation 4
# Some categories contain significantly more books than others, indicating an uneven distribution across genres.
#
# ## Observation 5
# Higher-rated books do not always have higher prices, suggesting that price and rating have only a weak relationship.

# %% [markdown]
# # Limitations
#
# - The dataset contains only 105 books, so it may not represent the entire bookstore.
# - Ratings are represented as star values instead of detailed customer review scores.
# - The dataset does not include sales, author popularity, or publication details.
# - Price alone cannot determine the quality or popularity of a book.
# - Since the data was scraped from a demo website, the findings may not generalize to real-world online bookstores.
